# %%
import django 
django.setup()

import ccxt
from coinsapp.models import Coin, Value, Coinproperties
import requests
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties

# %%
from coinsapp.get_and_filter_coin_data import get_my_coin_data, delete_old_values, update_my_markers, make_coin_properties, get_coin_ful_name, get_my_symbols

#get_my_coin_data()
#delete_old_values()
#update_my_markers()
make_coin_properties()
#get_my_symbols()

# %%
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties


t=datetime.now()-timedelta(hours=2)
t_half=datetime.now()-timedelta(minutes=30)
coin=Coin.objects.get(coin_ticker="BLZ BlazeCoin")

#for ticker in coin:

volume=coin.value_set.filter(reqtime__gt=t).order_by('reqtime')
type(volume)

# # # #VOLUME CHANEG 1 HOUR
# Lastvolume=volume.last().coin_basevolume
# Firstvolume=volume.first().coin_basevolume
# volumechange=(Lastvolume-Firstvolume)/Firstvolume*100
# print('#VOLUME CHANEG 1 HOUR')
# print('Lastvolume',Lastvolume)
# print('Firstvolume',Firstvolume)
# print('volumechange',volumechange)


# #PRICE CHANGE 1 HOUR
# Lastprice=volume.last().coin_value
# Firstprice=volume.first().coin_value
# pricechange=(Lastprice-Firstprice)/Firstprice*100
# print('#PRICE CHANGE 1 HOUR')
# print('Lastprice',Lastprice)
# print('Firstprice',Firstprice)
# print('pricechange',pricechange)

volume_half=coin.value_set.filter(reqtime__gt=t_half).order_by('reqtime')

#VOLUME CHANGE 30 MIN
Last_volumehalf=volume_half.first().coin_basevolume
First_volumehalf=volume_half.last().coin_basevolume
volume_changehalf=(Last_volumehalf-First_volumehalf)/First_volumehalf*100
print('#PRICE CHANGE 30')
print('Last_volumehalf',Last_volumehalf)
print('First_volumehalf',First_volumehalf)
print('volume_changehalf',volume_changehalf)


#PRICE CHANEG 30 MIN
Last_pricehalf=volume_half.first().coin_value
First_pricehalf=volume_half.last().coin_value
price_changehalf=(Last_pricehalf-First_pricehalf)/First_pricehalf*100

print('#PRICE CHANGE 30')
print('Last_pricehalf',Last_pricehalf)
print('First_pricehalf',First_pricehalf)
print('price_changehalf',price_changehalf)

coin
# Out:
# #PRICE CHANGE 30
# ('Last_volumehalf', 1115419.0)
# ('First_volumehalf', 1122667.0)
# ('volume_changehalf', -0.6456055090244925)
# #PRICE CHANGE 30
# ('Last_pricehalf', 0.00183289)
# ('First_pricehalf', 0.0018448)
# ('price_changehalf', -0.6455984388551582)

# %%
t=datetime.now()-timedelta(hours=3)

coin=Coin.objects.get(coin_ticker='CND Cindicator')

volume=coin.value_set.filter(reqtime__gt=t).order_by('reqtime')

for value in volume:
    print(value.coin_value, value.reqtime)
    
print('Last',volume.last())
print('First',volume.first())
# Out:
# (0.165988, datetime.datetime(2018, 2, 20, 14, 51, 25, 86975))
# (0.166974, datetime.datetime(2018, 2, 20, 15, 1, 24, 832935))
# (0.165396, datetime.datetime(2018, 2, 20, 15, 11, 25, 525984))
# (0.169317, datetime.datetime(2018, 2, 20, 16, 1, 26, 366355))
# (0.168487, datetime.datetime(2018, 2, 20, 16, 11, 26, 979220))
# (0.168274, datetime.datetime(2018, 2, 20, 16, 21, 27, 388302))
# (0.171153, datetime.datetime(2018, 2, 20, 16, 31, 26, 693380))
# (0.167669, datetime.datetime(2018, 2, 20, 16, 41, 27, 43092))
# (0.169558, datetime.datetime(2018, 2, 20, 16, 51, 27, 578316))
# (0.171085, datetime.datetime(2018, 2, 20, 17, 1, 26, 586169))
# (0.170411, datetime.datetime(2018, 2, 20, 17, 11, 26, 906885))
# (0.170818, datetime.datetime(2018, 2, 20, 17, 21, 27, 113192))
# (0.171552, datetime.datetime(2018, 2, 20, 17, 41, 29, 270689))
# ('Last', <Value: value: 0.171552 time: 2018-02-20 17:41:29.270689 volume: 248060176.0>)
# ('First', <Value: value: 0.165988 time: 2018-02-20 14:51:25.086975 volume: 240014762.0>)

# %%
# for row in Coin.objects.all():
#     if Coin.objects.filter(coin_name=row.coin_name).count() > 1:
#          row.delete()
Coinproperties.objects.all().delete()
# Out:
# (218, {u'coinsapp.Coinproperties': 218})

# %%
coins=Coin.objects.exclude(value__coin_value__isnull=True, value__coin_basevolume__isnull=True )

for symbol in coins:

    volume=symbol.value_set.all()

    print(symbol.coin_ticker)
# Out:
# POWR Power Ledger
# LINK ChainLink
# FUN FunFair
# CND Cindicator
# SALT SALT
# NEBL Neblio
# ENG Enigma
# BNT Bancor
# OST Simple Token
# SNGLS SingularDTV
# WABI WaBi
# INS INS Ecosystem
# VIA Viacoin
# BRD Bread
# GTO Gifto
# NULS Nuls
# WINGS Wings
# TNT Tierion
# RDN Raiden Network Token
# DASH Dash
# XMR Monero
# ETC Ethereum Classic
# VEN VeChain
# TRX TRON
# LSK Lisk
# QTUM Qtum
# BTG Bitcoin Gold
# OMG OmiseGO
# ICX ICON
# ZEC Zcash
# REQ Request Network
# QSP Quantstamp
# ENJ Enjin Coin
# ICN Iconomi
# CTR Centra
# TRIG Triggers
# XVG Verge
# POE Po.et
# STEEM Steem
# NANO Nano
# BNB Binance Coin
# PPT Populous
# STORJ Storj
# SUB Substratum
# LEND ETHLend
# MANA Decentraland
# NAV NAV Coin
# ADX AdEx
# MOD Modum
# CDT CoinDash
# DNT district0x
# EVX Everex
# VIB Viberate
# MTH Monetha
# LUN Lunyr
# BCPT BlockMason Credit Protocol
# DLT Agrello
# ARN Aeron
# MDA Moeda Loyalty Points
# OAX OAX
# BLZ BlazeCoin
# BTC Bitcoin
# ETH Ethereum
# XRP Ripple
# BCH Bitcoin Cash
# LTC Litecoin
# STRAT Stratis
# WAVES Waves
# SNT Status
# BTS BitShares
# AE Aeternity
# WTC Waltonchain
# ZRX 0x
# DGD DigixDAO
# KMD Komodo
# HSR Hshare
# GAS Gas
# ARK Ark
# LRC Loopring
# ELF aelf
# PIVX PIVX
# AION Aion
# TNB Time New Bank
# MCO Monaco
# RLC iExec RLC
# RPX Red Pulse
# VIBE VIBE
# AMB Ambrosus
# FUEL Etherparty
# GVT Genesis Vision
# SNM SONM
# BLZ Bluzelle
# EDO Eidoo
# MTL Metal
# AST AirSwap
# APPC AppCoins
# BTG Bitgem
# CMT Comet
# ICN iCoin
# KNC KingN Coin
# ADA Cardano
# KNC Kyber Network
# IOST IOStoken
# GXS GXShares
# XZC ZCoin
# CMT CyberMiles
# NEO NEO
# XLM Stellar
# EOS EOS

# %%
import numpy as np
from numpy import convolve

coins_id='SALT SALT'


c = Coin.objects.get(coin_ticker=coins_id)
x=[]
y=[]
for values in c.value_set.order_by('reqtime'):
    x.append(values.reqtime)
    y.append(values.coin_value)
        # create a new plot with a title and axis labels

window = 5

weights = np.repeat(1.0, window)/window
sma = list(np.convolve(y, weights, 'valid'))

n=0

while (n < window-1):
    n=n+1
    nan = float('nan')
    sma.insert(0,nan)
    
    
print(sma)
# Out:
# [nan, nan, nan, nan, 4.198958, 4.198678, 4.201364, 4.2131680000000005, 4.220302, 4.2328920000000005, 4.242458, 4.256486, 4.268706, 4.275076, 4.2831779999999995, 4.299228, 4.30574, 4.3044, 4.31383, 4.301088, 4.280486, 4.261624, 4.248609999999999, 4.210134, 4.19688, 4.192698, 4.181776, 4.172560000000001, 4.1786460000000005, 4.17108, 4.152734000000001, 4.142354000000001, 4.136282, 4.130470000000001, 4.125242, 4.116254, 4.105686, 4.0712280000000005, 4.038556, 4.007618000000001, 3.9900979999999997, 3.969916, 3.9693320000000005, 3.970034, 3.9753140000000005, 3.972146, 3.977582, 3.98301, 3.9809140000000003, 3.987276, 3.9956080000000003, 3.981752, 3.9612040000000004, 3.9351180000000006, 3.8976140000000004, 3.8567660000000004, 3.823316, 3.7983220000000006, 3.7810580000000007, 3.7590500000000002, 3.7423740000000003, 3.73886, 3.7484480000000007, 3.7543580000000008, 3.769374, 3.76803, 3.772984, 3.761364, 3.75772, 3.753502, 3.7699200000000004, 3.78518, 3.794796, 3.797766]

# %%
coin=Coin.objects.all()

for symbol in coin:
    print(symbol.id)
00
# Out:
# 2837
# 2838
# 2834
# 2843
# 2839
# 2841
# 2854
# 2867
# 2873
# 2845
# 2874
# 2875
# 2871
# 2876
# 2878
# 2877
# 2879
# 2901
# 2902
# 2906
# 2844
# 2903
# 2909
# 2907
# 2913
# 2920
# 2904
# 2842
# 2847
# 2846
# 2848
# 2881
# 2916
# 2880
# 2918
# 2912
# 2850
# 2911
# 2849
# 2852
# 2851
# 2853
# 2855
# 2856
# 2882
# 2890
# 2883
# 2887
# 2886
# 2884
# 2888
# 2889
# 2885
# 2892
# 2897
# 2915
# 2914
# 2919
# 2917
# 2921
# 2922
# 2923
# 2924
# 2925
# 2822
# 2823
# 2824
# 2825
# 2858
# 2857
# 2859
# 2894
# 2863
# 2826
# 2828
# 2893
# 2926
# 2895
# 2927
# 2929
# 2860
# 2827
# 2899
# 2829
# 2830
# 2861
# 2862
# 2891
# 2928
# 2930
# 2940
# 2831
# 2832
# 2833
# 2835
# 2865
# 2866
# 2900
# 2905
# 2896
# 2864
# 2939
# 2868
# 2870
# 2898
# 2908
# 2910
# 2836
# 2840
# 2869
# 2872

# %%
    coin=Coin.objects.get(coin_ticker='SALT SALT')
    
    
    window=20
    sum=0
    c=coin.value_set.order_by('-reqtime').count()
    print(c)
    if coin.value_set.order_by('-reqtime').count()>window:

        for  smas in coin.value_set.order_by('-reqtime')[:window]:
            sum=sum+smas.coin_value
        sum=sum/20
        
        
sum
# Out:
# 76
# 4.2117645

# %%
c=Coin.objects.exclude(value__coin_value__isnull=True, value__coin_basevolume__isnull=True )

for gems in c:
    last_change=gems.coinproperties_set.last().coin_changehalf 
    price=gems.value_set.last().coin_value
    sma=gems.value_set.last().sma
    time=gems.value_set.last().reqtime
    if price  <  sma-0.02*price:
        print(gems.coin_ticker, ' price:', price, '<',' sma:',sma, ' price change:', last_change  )
        dip=(sma-price)/sma*100>0 
        print(dip)
        Gems.objects.update_or_create(gem_name=gems.coin_ticker, defaults={'gemStartPrice':price,'gemDip':dip,'gemReqtime':time})
        
    elif Gems.objects.filter(gem_name=gems.coin_ticker).exists():
         Gems.objects.get(gem_name=gems.coin_ticker).delete()
                       
                      
# print(coins.value_set.all().last().coin_value)
# print(coins.value_set.all().last().sma)
# Out:
# (u'OAX OAX', ' price:', 0.896188, '<', ' sma:', 0.9069192, ' price change:', 0.401124785289364)
# True
# (u'BCPT BlockMason Credit Protocol', ' price:', 1.26546, '<', ' sma:', 1.282661, ' price change:', 0.921851588991403)
# True

# %%
records=Gems.objects.all()

for gems in records:
    print (gems.gem_name, ' ', gems.gemDip)
# Out:
# (u'LUN Lunyr', ' ', 2.36246241009989)
# (u'HSR Hshare', ' ', 2.27233038555618)
# (u'BLZ BlazeCoin', ' ', 7.13202089928372)
# (u'AMB Ambrosus', ' ', 1.99796760330104)
# (u'DGD DigixDAO', ' ', 2.89587098667054)

# %%
from coinsapp.my_telegram import send_to_telegram

send_to_telegram('hello <a href="http://139.59.127.165/">Coin_name </a>')

# %%
# t=datetime.now()-timedelta(hours=2)
# t_half=datetime.now()-timedelta(minutes=10)
coins=Coin.objects.exclude(value__coin_value__isnull=True)

for symbol in coins:
    print(symbol)
    volume=symbol.coinproperties_set.last().coin_changehalf
    print(volume)
    
#     #PRICE CHANGE 2 HOURS
#     Lastprice=volume.last().coin_value
#     Firstprice=volume.first().coin_value
#     price_change=(Lastprice-Firstprice)/Firstprice*100

#     volume_half=symbol.value_set.filter(reqtime__gt=t_half).order_by('reqtime')

#     if volume_half.count() > 2:
#         #PRICE CHANEG 10 MIN
#         Last_pricehalf=volume_half.last().coin_value
#         First_pricehalf=volume_half.first().coin_value
#         price_changehalf=(Last_pricehalf-First_pricehalf)/First_pricehalf*100
# Out:
# IOST IOStoken
# -0.147616677252
# SNGLS SingularDTV
# 1.68508334914
# APPC AppCoins
# -0.128189301002
# OST Simple Token
# -0.398383607494
# NULS Nuls
# 0.0188467977073
# CMT CyberMiles
# -0.352633777784
# INS INS Ecosystem
# 0.127015012093
# WINGS Wings
# -0.658581097587
# POA POA Network
# -0.338620843461
# NCASH Nucleus Vision
# -1.70257123002
# WABI WaBi
# 1.8863261944
# TRX TRON
# 1.5449535464
# VEN VeChain
# -0.256576736068
# OMG OmiseGO
# -0.244037204162
# FUEL Etherparty
# 0.189014261985
# NANO Nano
# 1.87766025595
# QTUM Qtum
# -0.00714785526721
# LSK Lisk
# -0.434766685676
# BTG Bitcoin Gold
# 0.131760353222
# ICX ICON
# -0.0315339071055
# ZEC Zcash
# 0.247122193552
# SALT SALT
# -0.593149127576
# NEBL Neblio
# -0.115752981961
# XZC ZCoin
# 0.609074499054
# POWR Power Ledger
# 0.187889597203
# BNT Bancor
# -0.189206926145
# ENG Enigma
# 0.362085644903
# REQ Request Network
# -0.338511237886
# CND Cindicator
# -0.753029102027
# QSP Quantstamp
# 0.192383300824
# ENJ Enjin Coin
# -0.210695782303
# ICN Iconomi
# 0.149769996077
# BCPT BlockMason Credit Protocol
# -2.52361386964
# BRD Bread
# -0.789423613657
# GTO Gifto
# 0.243358013937
# MOD Modum
# 0.0271627078929
# DGD DigixDAO
# -0.376409096228
# BNB Binance Coin
# 0.155080061271
# STEEM Steem
# 0.684286955554
# RDN Raiden Network Token
# 0.207629056075
# VIA Viacoin
# 0.816191773723
# XVG Verge
# -0.0209084638176
# SUB Substratum
# -0.482103751442
# POE Po.et
# 0.118120746465
# STORJ Storj
# -0.0928102957555
# MANA Decentraland
# -0.0355849156455
# CDT CoinDash
# -0.822053256637
# LUN Lunyr
# -1.31729796561
# TRIG Triggers
# -0.794641345183
# TNT Tierion
# -0.300565617719
# DNT district0x
# -0.751565870588
# STRAT Stratis
# 0.0842007345512
# PPT Populous
# -0.945313826694
# WAVES Waves
# 0.00764549851771
# BTS BitShares
# -1.0311061153
# SNT Status
# 0.333882735051
# AE Aeternity
# -0.101186126258
# WTC Waltonchain
# -0.621902723971
# ZRX 0x
# 0.092832442227
# HSR Hshare
# -0.0327113257162
# NAV NAV Coin
# -0.933098879084
# RLC iExec RLC
# -0.47009535019
# TNB Time New Bank
# 0.0696196481195
# LEND ETHLend
# -0.0942728725267
# CTR Centra
# -0.677965573497
# MCO Monaco
# -0.0397006824675
# VIB Viberate
# 0.549265777379
# BTC Bitcoin
# 0.0208140172946
# RPX Red Pulse
# -0.384172522518
# ETH Ethereum
# -0.0494127921675
# XRP Ripple
# -0.00151707905933
# BCH Bitcoin Cash
# 0.047380588663
# ADX AdEx
# 0.295706224918
# EVX Everex
# -1.07573571042
# GVT Genesis Vision
# -0.353681717616
# MTH Monetha
# -0.148419766021
# DLT Agrello
# 0.454048156089
# KMD Komodo
# -0.340987315699
# LTC Litecoin
# 0.0230743715839
# MTL Metal
# -0.143625633258
# NEO NEO
# 0.0384800384801
# ADA Cardano
# 0.180076761267
# GAS Gas
# 0.153254741158
# ARK Ark
# 0.0819178211526
# BLZ Bluzelle
# -0.598909701394
# ARN Aeron
# 2.5712225027
# MDA Moeda Loyalty Points
# -0.010711313619
# XLM Stellar
# -0.206383156825
# EOS EOS
# -0.0188060044554
# DASH Dash
# 0.030778597606
# XMR Monero
# 0.0801282051282
# LRC Loopring
# -0.799008273182
# PIVX PIVX
# 0.0346054615028
# VIBE VIBE
# 0.573073207043
# SNM SONM
# 0.472247196328
# EDO Eidoo
# -0.0111943611301
# ELF aelf
# -0.109479706524
# OAX OAX
# -0.369533976596
# AION Aion
# -0.278960914128
# GXS GXShares
# 0.0165595240743
# AMB Ambrosus
# 0.0817222974181
# AST AirSwap
# -0.332037406746
# BLZ BlazeCoin
# -0.0554982954095
# BTG Bitgem
# -0.0117417065416
# CMT Comet
# -0.0809012275088
# KNC Kyber Network
# 0.0204857900594
# LINK ChainLink
# -0.394777986241
# FUN FunFair
# 0.343139990724
# ICN iCoin
# -0.0561081667876
# KNC KingN Coin
# -10.7503683806
# ETC Ethereum Classic
# -0.0298181388758
