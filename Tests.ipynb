# %%
import django 
django.setup()

import ccxt
from coinsapp.models import Coin, Value, Coinproperties
import requests
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties

# %%
from coinsapp.get_and_filter_coin_data import get_my_coin_data, delete_old_values, update_my_markers, make_coin_properties, get_coin_ful_name, get_my_symbols

get_my_coin_data()
#delete_old_values()
#update_my_markers()
#make_coin_properties()
#get_my_symbols()
# Out:
# ('GET', 'https://api.binance.com/api/v1/exchangeInfo', '\nRequest:', {'Accept-Encoding': 'gzip, deflate'}, None)
# ('GET', 'https://api.binance.com/api/v1/exchangeInfo', '\nResponse:', "{'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains', 'Server': 'nginx', 'Connection': 'keep-alive', 'Date': 'Thu, 22 Feb 2018 17:06:37 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'application/json'}", u'{"timezone":"UTC","serverTime":1519319197567,"rateLimits":[{"rateLimitType":"REQUESTS","interval":"MINUTE","limit":1200},{"rateLimitType":"ORDERS","interval":"SECOND","limit":10},{"rateLimitType":"ORDERS","interval":"DAY","limit":100000}],"exchangeFilters":[],"symbols":[{"symbol":"ETHBTC","status":"TRADING","baseAsset":"ETH","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.00100000","maxQty":"100000.00000000","stepSize":"0.00100000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"LTCBTC","status":"TRADING","baseAsset":"LTC","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"100000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"BNBBTC","status":"TRADING","baseAsset":"BNB","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000010","maxPrice":"100000.00000000","tickSize":"0.00000010"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"90000000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"NEOBTC","status":"TRADING","baseAsset":"NEO","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"100000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"123456","status":"TRADING","baseAsset":"123","baseAssetPrecision":8,"quoteAsset":"456","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.00100000","maxQty":"100000.00000000","stepSize":"0.00100000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"QTUMETH","status":"TRADING","baseAsset":"QTUM","baseAssetPrecision":8,"quoteAsset":"ETH","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"90000000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.01000000"}]},{"symbol":"EOSETH","status":"TRADING","baseAsset":"EOS","baseAssetPrecision":8,"quoteAsset":"ETH","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","m ...
# ('GET', 'https://api.binance.com/api/v1/exchangeInfo', '\nRequest:', {'Accept-Encoding': 'gzip, deflate'}, None)
# ('GET', 'https://api.binance.com/api/v1/exchangeInfo', '\nResponse:', "{'Content-Encoding': 'gzip', 'Transfer-Encoding': 'chunked', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains', 'Server': 'nginx', 'Connection': 'keep-alive', 'Date': 'Thu, 22 Feb 2018 17:06:38 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'Content-Type': 'application/json'}", u'{"timezone":"UTC","serverTime":1519319198586,"rateLimits":[{"rateLimitType":"REQUESTS","interval":"MINUTE","limit":1200},{"rateLimitType":"ORDERS","interval":"SECOND","limit":10},{"rateLimitType":"ORDERS","interval":"DAY","limit":100000}],"exchangeFilters":[],"symbols":[{"symbol":"ETHBTC","status":"TRADING","baseAsset":"ETH","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.00100000","maxQty":"100000.00000000","stepSize":"0.00100000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"LTCBTC","status":"TRADING","baseAsset":"LTC","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"100000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"BNBBTC","status":"TRADING","baseAsset":"BNB","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000010","maxPrice":"100000.00000000","tickSize":"0.00000010"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"90000000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"NEOBTC","status":"TRADING","baseAsset":"NEO","baseAssetPrecision":8,"quoteAsset":"BTC","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"100000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"123456","status":"TRADING","baseAsset":"123","baseAssetPrecision":8,"quoteAsset":"456","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.00100000","maxQty":"100000.00000000","stepSize":"0.00100000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.00100000"}]},{"symbol":"QTUMETH","status":"TRADING","baseAsset":"QTUM","baseAssetPrecision":8,"quoteAsset":"ETH","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","minQty":"0.01000000","maxQty":"90000000.00000000","stepSize":"0.01000000"},{"filterType":"MIN_NOTIONAL","minNotional":"0.01000000"}]},{"symbol":"EOSETH","status":"TRADING","baseAsset":"EOS","baseAssetPrecision":8,"quoteAsset":"ETH","quotePrecision":8,"orderTypes":["LIMIT","LIMIT_MAKER","MARKET","STOP_LOSS_LIMIT","TAKE_PROFIT_LIMIT"],"icebergAllowed":true,"filters":[{"filterType":"PRICE_FILTER","minPrice":"0.00000100","maxPrice":"100000.00000000","tickSize":"0.00000100"},{"filterType":"LOT_SIZE","m ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-eb67fc8ca58a> in <module>()
#       1 from coinsapp.get_and_filter_coin_data import get_my_coin_data, delete_old_values, update_my_markers, make_coin_properties, get_coin_ful_name, get_my_symbols
#       2
# ----> 3 get_my_coin_data()
#       4 #delete_old_values()
#       5 #update_my_markers()
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/webapp/coinsapp/get_and_filter_coin_data.py in get_my_coin_data()
#     104
#     105                 for_values=Coin.objects.get(coin_ticker=str(ticker['symbol'])+" "+str(ticker['name']))
# --> 106                 v=for_values.value_set.create(coin_value=price, reqtime=datetime.now(),coin_basevolume=basevolume,)
#     107                 v.save()
#     108
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/fields/related_descriptors.pyc in create(self, **kwargs)
#     648             kwargs[self.field.name] = self.instance
#     649             db = router.db_for_write(self.model, instance=self.instance)
# --> 650             return super(RelatedManager, self.db_manager(db)).create(**kwargs)
#     651         create.alters_data = True
#     652
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/manager.pyc in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/query.pyc in create(self, **kwargs)
#     391         obj = self.model(**kwargs)
#     392         self._for_write = True
# --> 393         obj.save(force_insert=True, using=self.db)
#     394         return obj
#     395
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/base.pyc in save(self, force_insert, force_update, using, update_fields)
#     804
#     805         self.save_base(using=using, force_insert=force_insert,
# --> 806                        force_update=force_update, update_fields=update_fields)
#     807     save.alters_data = True
#     808
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/base.pyc in save_base(self, raw, force_insert, force_update, using, update_fields)
#     834             if not raw:
#     835                 self._save_parents(cls, using, update_fields)
# --> 836             updated = self._save_table(raw, cls, force_insert, force_update, using, update_fields)
#     837         # Store the database on which the object was saved
#     838         self._state.db = using
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/base.pyc in _save_table(self, raw, cls, force_insert, force_update, using, update_fields)
#     920
#     921             update_pk = meta.auto_field and not pk_set
# --> 922             result = self._do_insert(cls._base_manager, using, fields, update_pk, raw)
#     923             if update_pk:
#     924                 setattr(self, meta.pk.attname, result)
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/base.pyc in _do_insert(self, manager, using, fields, update_pk, raw)
#     959         """
#     960         return manager._insert([self], fields=fields, return_id=update_pk,
# --> 961                                using=using, raw=raw)
#     962
#     963     def delete(self, using=None, keep_parents=False):
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/manager.pyc in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/query.pyc in _insert(self, objs, fields, return_id, raw, using)
#    1058         query = sql.InsertQuery(self.model)
#    1059         query.insert_values(fields, objs, raw=raw)
# -> 1060         return query.get_compiler(using=using).execute_sql(return_id)
#    1061     _insert.alters_data = True
#    1062     _insert.queryset_only = False
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/sql/compiler.pyc in execute_sql(self, return_id)
#    1096         self.return_id = return_id
#    1097         with self.connection.cursor() as cursor:
# -> 1098             for sql, params in self.as_sql():
#    1099                 cursor.execute(sql, params)
#    1100             if not (return_id and cursor):
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/sql/compiler.pyc in as_sql(self)
#    1049             value_rows = [
#    1050                 [self.prepare_value(field, self.pre_save_val(field, obj)) for field in fields]
# -> 1051                 for obj in self.query.objs
#    1052             ]
#    1053         else:
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/sql/compiler.pyc in prepare_value(self, field, value)
#     988                 raise FieldError("Aggregate functions are not allowed in this query")
#     989         else:
# --> 990             value = field.get_db_prep_save(value, connection=self.connection)
#     991         return value
#     992
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/fields/__init__.pyc in get_db_prep_save(self, value, connection)
#     764         """
#     765         return self.get_db_prep_value(value, connection=connection,
# --> 766                                       prepared=False)
#     767
#     768     def has_default(self):
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/fields/__init__.pyc in get_db_prep_value(self, value, connection, prepared)
#     756         """
#     757         if not prepared:
# --> 758             value = self.get_prep_value(value)
#     759         return value
#     760
#
# /media/diff7/DATA/projects/CRYPTO/TRADER/virtual_crypto/local/lib/python2.7/site-packages/django/db/models/fields/__init__.pyc in get_prep_value(self, value)
#    1775         if value is None:
#    1776             return None
# -> 1777         return float(value)
#    1778
#    1779     def get_internal_type(self):
#
# TypeError: float() argument must be a string or a number

# %%
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties


t=datetime.now()-timedelta(hours=2)
t_half=datetime.now()-timedelta(minutes=30)
coin=Coin.objects.get(coin_ticker="BLZ BlazeCoin")

#for ticker in coin:

volume=coin.value_set.filter(reqtime__gt=t).order_by('reqtime')
type(volume)

# # # #VOLUME CHANEG 1 HOUR
# Lastvolume=volume.last().coin_basevolume
# Firstvolume=volume.first().coin_basevolume
# volumechange=(Lastvolume-Firstvolume)/Firstvolume*100
# print('#VOLUME CHANEG 1 HOUR')
# print('Lastvolume',Lastvolume)
# print('Firstvolume',Firstvolume)
# print('volumechange',volumechange)


# #PRICE CHANGE 1 HOUR
# Lastprice=volume.last().coin_value
# Firstprice=volume.first().coin_value
# pricechange=(Lastprice-Firstprice)/Firstprice*100
# print('#PRICE CHANGE 1 HOUR')
# print('Lastprice',Lastprice)
# print('Firstprice',Firstprice)
# print('pricechange',pricechange)

volume_half=coin.value_set.filter(reqtime__gt=t_half).order_by('reqtime')

#VOLUME CHANGE 30 MIN
Last_volumehalf=volume_half.first().coin_basevolume
First_volumehalf=volume_half.last().coin_basevolume
volume_changehalf=(Last_volumehalf-First_volumehalf)/First_volumehalf*100
print('#PRICE CHANGE 30')
print('Last_volumehalf',Last_volumehalf)
print('First_volumehalf',First_volumehalf)
print('volume_changehalf',volume_changehalf)


#PRICE CHANEG 30 MIN
Last_pricehalf=volume_half.first().coin_value
First_pricehalf=volume_half.last().coin_value
price_changehalf=(Last_pricehalf-First_pricehalf)/First_pricehalf*100

print('#PRICE CHANGE 30')
print('Last_pricehalf',Last_pricehalf)
print('First_pricehalf',First_pricehalf)
print('price_changehalf',price_changehalf)

coin
# Out:
# #PRICE CHANGE 30
# ('Last_volumehalf', 1115419.0)
# ('First_volumehalf', 1122667.0)
# ('volume_changehalf', -0.6456055090244925)
# #PRICE CHANGE 30
# ('Last_pricehalf', 0.00183289)
# ('First_pricehalf', 0.0018448)
# ('price_changehalf', -0.6455984388551582)

# %%
t=datetime.now()-timedelta(hours=3)

coin=Coin.objects.get(coin_ticker='CND Cindicator')

volume=coin.value_set.filter(reqtime__gt=t).order_by('reqtime')

for value in volume:
    print(value.coin_value, value.reqtime)
    
print('Last',volume.last())
print('First',volume.first())
# Out:
# (0.165988, datetime.datetime(2018, 2, 20, 14, 51, 25, 86975))
# (0.166974, datetime.datetime(2018, 2, 20, 15, 1, 24, 832935))
# (0.165396, datetime.datetime(2018, 2, 20, 15, 11, 25, 525984))
# (0.169317, datetime.datetime(2018, 2, 20, 16, 1, 26, 366355))
# (0.168487, datetime.datetime(2018, 2, 20, 16, 11, 26, 979220))
# (0.168274, datetime.datetime(2018, 2, 20, 16, 21, 27, 388302))
# (0.171153, datetime.datetime(2018, 2, 20, 16, 31, 26, 693380))
# (0.167669, datetime.datetime(2018, 2, 20, 16, 41, 27, 43092))
# (0.169558, datetime.datetime(2018, 2, 20, 16, 51, 27, 578316))
# (0.171085, datetime.datetime(2018, 2, 20, 17, 1, 26, 586169))
# (0.170411, datetime.datetime(2018, 2, 20, 17, 11, 26, 906885))
# (0.170818, datetime.datetime(2018, 2, 20, 17, 21, 27, 113192))
# (0.171552, datetime.datetime(2018, 2, 20, 17, 41, 29, 270689))
# ('Last', <Value: value: 0.171552 time: 2018-02-20 17:41:29.270689 volume: 248060176.0>)
# ('First', <Value: value: 0.165988 time: 2018-02-20 14:51:25.086975 volume: 240014762.0>)

# %%
# for row in Coin.objects.all():
#     if Coin.objects.filter(coin_name=row.coin_name).count() > 1:
#          row.delete()
Coinproperties.objects.all().delete()
# Out:
# (218, {u'coinsapp.Coinproperties': 218})

# %%
coins=Coin.objects.exclude(value__coin_value__isnull=True, value__coin_basevolume__isnull=True )

for symbol in coins:

    volume=symbol.value_set.all()

    print(symbol.coin_ticker)
# Out:
# POWR Power Ledger
# LINK ChainLink
# FUN FunFair
# CND Cindicator
# SALT SALT
# NEBL Neblio
# ENG Enigma
# BNT Bancor
# OST Simple Token
# SNGLS SingularDTV
# WABI WaBi
# INS INS Ecosystem
# VIA Viacoin
# BRD Bread
# GTO Gifto
# NULS Nuls
# WINGS Wings
# TNT Tierion
# RDN Raiden Network Token
# DASH Dash
# XMR Monero
# ETC Ethereum Classic
# VEN VeChain
# TRX TRON
# LSK Lisk
# QTUM Qtum
# BTG Bitcoin Gold
# OMG OmiseGO
# ICX ICON
# ZEC Zcash
# REQ Request Network
# QSP Quantstamp
# ENJ Enjin Coin
# ICN Iconomi
# CTR Centra
# TRIG Triggers
# XVG Verge
# POE Po.et
# STEEM Steem
# NANO Nano
# BNB Binance Coin
# PPT Populous
# STORJ Storj
# SUB Substratum
# LEND ETHLend
# MANA Decentraland
# NAV NAV Coin
# ADX AdEx
# MOD Modum
# CDT CoinDash
# DNT district0x
# EVX Everex
# VIB Viberate
# MTH Monetha
# LUN Lunyr
# BCPT BlockMason Credit Protocol
# DLT Agrello
# ARN Aeron
# MDA Moeda Loyalty Points
# OAX OAX
# BLZ BlazeCoin
# BTC Bitcoin
# ETH Ethereum
# XRP Ripple
# BCH Bitcoin Cash
# LTC Litecoin
# STRAT Stratis
# WAVES Waves
# SNT Status
# BTS BitShares
# AE Aeternity
# WTC Waltonchain
# ZRX 0x
# DGD DigixDAO
# KMD Komodo
# HSR Hshare
# GAS Gas
# ARK Ark
# LRC Loopring
# ELF aelf
# PIVX PIVX
# AION Aion
# TNB Time New Bank
# MCO Monaco
# RLC iExec RLC
# RPX Red Pulse
# VIBE VIBE
# AMB Ambrosus
# FUEL Etherparty
# GVT Genesis Vision
# SNM SONM
# BLZ Bluzelle
# EDO Eidoo
# MTL Metal
# AST AirSwap
# APPC AppCoins
# BTG Bitgem
# CMT Comet
# ICN iCoin
# KNC KingN Coin
# ADA Cardano
# KNC Kyber Network
# IOST IOStoken
# GXS GXShares
# XZC ZCoin
# CMT CyberMiles
# NEO NEO
# XLM Stellar
# EOS EOS

# %%
import numpy as np
from numpy import convolve

coins_id='SALT SALT'


c = Coin.objects.get(coin_ticker=coins_id)
x=[]
y=[]
for values in c.value_set.order_by('reqtime'):
    x.append(values.reqtime)
    y.append(values.coin_value)
        # create a new plot with a title and axis labels

window = 5

weights = np.repeat(1.0, window)/window
sma = list(np.convolve(y, weights, 'valid'))

n=0

while (n < window-1):
    n=n+1
    nan = float('nan')
    sma.insert(0,nan)
    
    
print(sma)
# Out:
# [nan, nan, nan, nan, 4.198958, 4.198678, 4.201364, 4.2131680000000005, 4.220302, 4.2328920000000005, 4.242458, 4.256486, 4.268706, 4.275076, 4.2831779999999995, 4.299228, 4.30574, 4.3044, 4.31383, 4.301088, 4.280486, 4.261624, 4.248609999999999, 4.210134, 4.19688, 4.192698, 4.181776, 4.172560000000001, 4.1786460000000005, 4.17108, 4.152734000000001, 4.142354000000001, 4.136282, 4.130470000000001, 4.125242, 4.116254, 4.105686, 4.0712280000000005, 4.038556, 4.007618000000001, 3.9900979999999997, 3.969916, 3.9693320000000005, 3.970034, 3.9753140000000005, 3.972146, 3.977582, 3.98301, 3.9809140000000003, 3.987276, 3.9956080000000003, 3.981752, 3.9612040000000004, 3.9351180000000006, 3.8976140000000004, 3.8567660000000004, 3.823316, 3.7983220000000006, 3.7810580000000007, 3.7590500000000002, 3.7423740000000003, 3.73886, 3.7484480000000007, 3.7543580000000008, 3.769374, 3.76803, 3.772984, 3.761364, 3.75772, 3.753502, 3.7699200000000004, 3.78518, 3.794796, 3.797766]

# %%
coin=Coin.objects.get(coin_ticker='SALT SALT')

window=20
sum=0
print(coin.value_set.order_by('reqtime'))



for  price in coin.value_set.all().reverse()[:window]:
    sum=+price.coin_value
    
sum=sum/20

print(sum)
# Out:
# <QuerySet [<Value: value: 4.20539 time: 2018-02-22 04:11:39.381115 volume: 226761524.0>, <Value: value: 4.19942 time: 2018-02-22 04:21:39.550485 volume: 226439612.0>, <Value: value: 4.17202 time: 2018-02-22 04:31:39.487090 volume: 224962159.0>, <Value: value: 4.21333 time: 2018-02-22 04:41:39.700066 volume: 227189662.0>, <Value: value: 4.20463 time: 2018-02-22 04:51:39.910154 volume: 226720543.0>, <Value: value: 4.20399 time: 2018-02-22 05:01:39.959359 volume: 226686034.0>, <Value: value: 4.21285 time: 2018-02-22 05:11:40.184493 volume: 227163779.0>, <Value: value: 4.23104 time: 2018-02-22 05:21:39.914343 volume: 228144614.0>, <Value: value: 4.249 time: 2018-02-22 05:31:39.994545 volume: 229113047.0>, <Value: value: 4.26758 time: 2018-02-22 05:41:40.651399 volume: 230114911.0>, <Value: value: 4.25182 time: 2018-02-22 05:51:40.084023 volume: 229265106.0>, <Value: value: 4.28299 time: 2018-02-22 06:01:40.239880 volume: 230945843.0>, <Value: value: 4.29214 time: 2018-02-22 06:11:40.355221 volume: 231439226.0>, <Value: value: 4.28085 time: 2018-02-22 06:21:40.475178 volume: 230830451.0>, <Value: value: 4.30809 time: 2018-02-22 06:31:40.523500 volume: 232299276.0>, <Value: value: 4.33207 time: 2018-02-22 06:41:40.529390 volume: 233592317.0>, <Value: value: 4.31555 time: 2018-02-22 06:51:40.601033 volume: 232701532.0>, <Value: value: 4.28544 time: 2018-02-22 07:01:40.839916 volume: 231077951.0>, <Value: value: 4.328 time: 2018-02-22 07:11:41.124379 volume: 233372856.0>, <Value: value: 4.24438 time: 2018-02-22 07:21:40.936439 volume: 228863929.0>, '...(remaining elements truncated)...']>
# 0.1898725
