# %%
import django 
django.setup()

import ccxt
from coinsapp.models import Coin, Value, Coinproperties
import requests
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties

# %%
from coinsapp.get_and_filter_coin_data import get_my_coin_data, delete_old_values, update_my_markers, make_coin_properties, get_coin_ful_name, get_my_symbols

#get_my_coin_data()
#delete_old_values()
#update_my_markers()
make_coin_properties()
#get_my_symbols()

# %%
from datetime import datetime, timedelta
from coinsapp.models import Coin, Value, Coinproperties


t=datetime.now()-timedelta(hours=2)
t_half=datetime.now()-timedelta(minutes=30)
coin=Coin.objects.all()

for ticker in coin:

    volume=ticker.value_set.filter(reqtime__gt=t).order_by('reqtime')
    type(volume)

    # # #VOLUME CHANEG 1 HOUR
    Lastvolume=volume.last().coin_basevolume
    Firstvolume=volume.first().coin_basevolume
    volumechange=(Lastvolume-Firstvolume)/Firstvolume*100
    print('#VOLUME CHANEG 1 HOUR')
    print('Lastvolume',Lastvolume)
    print('Firstvolume',Firstvolume)
    print('volumechange',volumechange)


# # #PRICE CHANGE 1 HOUR
# # Lastprice=volume.last().coin_value
# # Firstprice=volume.first().coin_value
# # pricechange=(Lastprice-Firstprice)/Firstprice*100
# # print('#PRICE CHANGE 1 HOUR')
# # print('Lastprice',Lastprice)
# # print('Firstprice',Firstprice)
# # print('pricechange',pricechange)

# # #!!!Publisher.objects.filter(id=1).update(name='Apress Publishing')

# # volume_half=coin.value_set.filter(reqtime__gt=t_half).order_by('reqtime')

# # #VOLUME CHANGE 30 MIN
# # Last_volumehalf=volume_half.last().coin_basevolume
# # First_volumehalf=volume_half.first().coin_basevolume
# # volume_changehalf=(Last_volumehalf-First_volumehalf)/First_volumehalf*100
# # print('#VOLUME CHANGE 30 MIN')
# # print('Last_volumehalf',Last_volumehalf)
# # print('Last_volumehalf',Last_volumehalf)
# # print('volume_changehalf',volume_changehalf)

# # #PRICE CHANEG 30 MIN
# # Last_pricehalf=volume_half.last().coin_value
# # First_pricehalf=volume_half.first().coin_value
# # price_changehalf=(Last_pricehalf-First_pricehalf)/First_pricehalf*100
# # print('#PRICE CHANEG 30 MIN')
# # print('Last_pricehalf',Last_pricehalf)
# # print('First_pricehalf',First_pricehalf)
# # print('price_changehalf',price_changehalf)
# Out:
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 181716395301.0)
# ('Firstvolume', 181996449535.0)
# ('volumechange', -0.153878954625509)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 94063342933.0)
# ('Firstvolume', 94197766445.0)
# ('volumechange', -0.1427035025065981)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 46385468461.0)
# ('Firstvolume', 46332415927.0)
# ('volumechange', 0.11450413914005267)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 25926709408.0)
# ('Firstvolume', 26007254366.0)
# ('volumechange', -0.3097018888133714)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 12594821806.0)
# ('Firstvolume', 12588690092.0)
# ('volumechange', 0.04870811780406485)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 10783198272.0)
# ('Firstvolume', 10777909150.0)
# ('volumechange', 0.04907372966676009)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 8777665000.0)
# ('Firstvolume', 8777080000.0)
# ('volumechange', 0.006665086794241365)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 8678516207.0)
# ('Firstvolume', 8700899389.0)
# ('volumechange', -0.2572513598800792)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 6793590706.0)
# ('Firstvolume', 6796390375.0)
# ('volumechange', -0.04119346955552122)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 5769357563.0)
# ('Firstvolume', 5771664049.0)
# ('volumechange', -0.039962235854660015)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 5061617145.0)
# ('Firstvolume', 5049535922.0)
# ('volumechange', 0.23925412526256307)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 3930960070.0)
# ('Firstvolume', 3988477144.0)
# ('volumechange', -1.4420810731365192)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume',

# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 84809680.0)
# ('Firstvolume', 84641839.0)
# ('volumechange', 0.19829554979305214)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 80372582.0)
# ('Firstvolume', 80806793.0)
# ('volumechange', -0.5373446759605965)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 78419922.0)
# ('Firstvolume', 78102268.0)
# ('volumechange', 0.40671546183524404)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 74748482.0)
# ('Firstvolume', 74265133.0)
# ('volumechange', 0.6508424350361024)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 73023063.0)
# ('Firstvolume', 72977644.0)
# ('volumechange', 0.062236868046877475)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 70944979.0)
# ('Firstvolume', 71116423.0)
# ('volumechange', -0.2410751170654351)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 68930428.0)
# ('Firstvolume', 69176291.0)
# ('volumechange', -0.35541512336936365)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 67966068.0)
# ('Firstvolume', 68204680.0)
# ('volumechange', -0.34984696064844817)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 67277686.0)
# ('Firstvolume', 65764840.0)
# ('volumechange', 2.300387258602013)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 65420400.0)
# ('Firstvolume', 65412600.0)
# ('volumechange', 0.011924308160813054)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 50093657.0)
# ('Firstvolume', 50009325.0)
# ('volumechange', 0.16863255002941951)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 47791281.0)
# ('Firstvolume', 47664586.0)
# ('volumechange', 0.26580530878837383)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 41802830.0)
# ('Firstvolume', 41911339.0)
# ('volumechange', -0.2589012963770974)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 37266167.0)
# ('Firstvolume', 37444315.0)
# ('volumechange', -0.4757678168234617)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 33732435.0)
# ('Firstvolume', 33499455.0)
# ('volumechange', 0.6954740009949415)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 29463312.0)
# ('Firstvolume', 30690749.0)
# ('volumechange', -3.999371276341285)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 27603516.0)
# ('Firstvolume', 27662403.0)
# ('volumechange', -0.212877384513558)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 26303030.0)
# ('Firstvolume', 26528060.0)
# ('volumechange', -0.8482716037282786)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 24237639.0)
# ('Firstvolume', 24558883.0)
# ('volumechange', -1.3080562336650245)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 1110203.0)
# ('Firstvolume', 1110094.0)
# ('volumechange', 0.009818988301891552)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 476286.0)
# ('Firstvolume', 476230.0)
# ('volumechange', 0.011759024001007916)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 203693.0)
# ('Firstvolume', 203673.0)
# ('volumechange', 0.009819661909040472)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 445102.0)
# ('Firstvolume', 445059.0)
# ('volumechange', 0.00966164036678283)
# #VOLUME CHANEG 1 HOUR
# ('Lastvolume', 67587.0)
# ('Firstvolume', 67580.0)
# ('volumechange', 0.010358094110683634)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2def0fd4f9fd> in <module>()
#      13
#      14     # # #VOLUME CHANEG 1 HOUR
# ---> 15     Lastvolume=volume.last().coin_basevolume
#      16     Firstvolume=volume.first().coin_basevolume
#      17     volumechange=(Lastvolume-Firstvolume)/Firstvolume*100
#
# AttributeError: 'NoneType' object has no attribute 'coin_basevolume'

# %%
t=datetime.now()-timedelta(hours=1)

coin=Coin.objects.get(coin_name='ADA')

volume=coin.value_set.filter(reqtime__gt=t).order_by('reqtime')

for value in volume:
    print(value.coin_value, value.reqtime)
# Out:
# (0.410579, datetime.datetime(2018, 2, 17, 15, 26, 55, 141593))
# (0.409571, datetime.datetime(2018, 2, 17, 15, 36, 55, 82145))
# (0.409367, datetime.datetime(2018, 2, 17, 15, 46, 55, 156131))
# (0.411482, datetime.datetime(2018, 2, 17, 15, 56, 55, 419765))
# (0.411893, datetime.datetime(2018, 2, 17, 16, 6, 55, 516417))
# (0.412575, datetime.datetime(2018, 2, 17, 16, 16, 55, 445511))

# %%
    coins=Coin.objects.all().values('coin_name')
    coins_to_delete = [c['coin_name'] for c in coins if c['coin_name'] not in all_names]
    print(coins_to_delete)
# Out:
# []
